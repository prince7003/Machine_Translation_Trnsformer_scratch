# %%
from pathlib import Path
import torch
import torch.nn as nn
from config import get_config, latest_weights_file_path
from train import get_model, get_ds, run_validation
from translate import translate

# %%
# Define the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
config = get_config()
train_dataloader, val_dataloader, tokenizer_src, tokenizer_tgt = get_ds(config)
model = get_model(config, tokenizer_src.get_vocab_size(), tokenizer_tgt.get_vocab_size()).to(device)

# Load the pretrained weights
model_filename = latest_weights_file_path(config)
state = torch.load(model_filename)
model.load_state_dict(state['model_state_dict'])
# Out:
# Using device: cuda
# Max length of source sentence: 309
# Max length of target sentence: 274
# <All keys matched successfully>

# %%
run_validation(model, val_dataloader, tokenizer_src, tokenizer_tgt, config['seq_len'], device, lambda msg: print(msg), 0, None, num_examples=10)
# Out:
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: And he goes like that with his hands,' said Tanya, standing up in the trap and mimicking Katavasov.
#     TARGET: E fa così con le braccia — disse Tanja, sollevandosi sul calesse e facendo il verso a Katavasov.
#  PREDICTED: E come si con gli occhi — disse Katavasov , sedendosi accanto a un ’ occhiata accanto a Katavasov .
# --------------------------------------------------------------------------------
#     SOURCE: 'You shan't be beheaded!' said Alice, and she put them into a large flower-pot that stood near.
#     TARGET: — Non vi decapiteranno! — disse Alice, e li mise in un grosso vaso da fiori accanto a lei.
#  PREDICTED: — Non vi prego di nulla ! — disse Alice , e si mise a un paio di .
# --------------------------------------------------------------------------------
#     SOURCE: 'Serezha, my dear little boy!' she uttered, catching her breath and embracing his plump little body.
#     TARGET: — Serëza! bambino caro! — ella esclamò, soffocando e abbracciandogli il corpo morbido.
#  PREDICTED: — Serëza , cara ! — ella ella si mise a parlare e si mise a il corpo .
# --------------------------------------------------------------------------------
#     SOURCE: You will find the boat easier to pull then, and it will not be so liable to upset, and it will not matter so much if it does upset; good, plain merchandise will stand water.
#     TARGET: Troverai che la tua barca si guida più facilmente e che sarà meno soggetta a rovesciarsi. Se poi si rovescia, che importa?
#  PREDICTED: il nostro viaggio per la barca , e non si , e se non si , e se non si , se ne .
# --------------------------------------------------------------------------------
#     SOURCE: He alighted first and helped her out.
#     TARGET: Uscì dalla carrozza e l’aiutò a discendere.
#  PREDICTED: Egli si voltò e si mise a parlare .
# --------------------------------------------------------------------------------
#     SOURCE: 'I'm afraid you will be cold upstairs,' remarked Dolly to Anna. 'I want to move you down, and then we shall be nearer to one another.'
#     TARGET: — Temo che avrai freddo di sopra — osservò Dolly rivolta ad Anna — vorrei farti venire giù, così staremo più vicine.
#  PREDICTED: — Io ti prego di — disse Dolly , — io ti prego di , e io ti .
# --------------------------------------------------------------------------------
#     SOURCE: 'Do you know, it came to me almost like an inspiration?' said she. 'Why must we wait here for the divorce?
#     TARGET: — Sai, m’è venuta quasi un’ispirazione — ella diceva. — Perché aspettare il divorzio qui?
#  PREDICTED: — E tu sai , come mai mai mai mai ? — disse lei . — Perché ci ?
# --------------------------------------------------------------------------------
#     SOURCE: 'In the study.'
#     TARGET: — Nello studio.
#  PREDICTED: — In quel momento .
# --------------------------------------------------------------------------------
#     SOURCE: Our work is not done here, at the elections, but at our homes.
#     TARGET: E il nostro lavoro da nobili non è qui alle elezioni, ma là, nel nostro angolo.
#  PREDICTED: Il nostro lavoro non è nulla , ma il nostro popolo si , ma la nostra vita è .
# --------------------------------------------------------------------------------
#     SOURCE: Vronsky glanced at them, frowned, and, as if he had not noticed them, turned his eyes on his book and began to eat and read at the same time.
#     TARGET: Vronskij li guardò, aggrottò le sopracciglia e, come se non li avesse notati, sbirciando il libro di traverso, prese a mangiare e a leggere insieme.
#  PREDICTED: Vronskij guardò il sorriso e , come se non avesse visto , non aveva visto , si avvicinava , si mise a parlare e cominciò a parlare .
# --------------------------------------------------------------------------------

# %%
t = translate("Why do I need to translate this?")
# Out:
# Using device: cuda
#     SOURCE: Why do I need to translate this?
#  PREDICTED: Perché io mi
